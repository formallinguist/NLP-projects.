# %% [markdown]
# <a href="https://colab.research.google.com/github/formallinguist/NLP-projects./blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bs4,
# Scrapy
# selenium

# %%
 from bs4 import BeautifulSoup

# %%
import requests

# %%
 r = requests.get('https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=2#reviews-filter-bar')

# %%
r
# Out:
# <Response [200]>

# %%
 content = r.content

# %%
content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41wZkyTaWoL.css,31Y8m1dzTdL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41CYNGpGlrL.css,01XPHJk60-L.css,114y0SIP+yL.css,21aPhFy+riL
# ...

# %%
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
for item in data :
  print(item,"\n\n\n to find the difference")
# Out:
# <div class="a-section review aok-relative" data-hook="review" id="R3SRJAS8OPOL1Y"><div class="a-row a-spacing-none" id="R3SRJAS8OPOL1Y-review-card"><div class="a-section celwidget" id="customer_review-R3SRJAS8OPOL1Y"><div class="a-row a-spacing-mini" data-hook="genome-widget"><a class="a-profile" data-a-size="small" href="/gp/profile/amzn1.account.AEH7QC3ZJO62WCFJ4PX43VYVAB5Q"><div aria-hidden="true" class="a-profile-avatar-wrapper"><div class="a-profile-avatar"><img class="a-lazy-loaded" data-src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/23e21bff-5741-48aa-ab6f-2461b9147c8f._CR1200,0,2160,2160_SX48_.jpg" src="https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif"/><noscript><img src="https://images-eu.ssl-images-amazon.com/images/S/amazon-avatars-global/23e21bff-5741-48aa-ab6f-2461b9147c8f._CR1200,0,2160,2160_SX48_.jpg"/></noscript></div></div><div class="a-profile-content"><span class="a-profile-name">Mayur</span></div></a>
# ...

# %%
 data = soup.find_all('div',attrs={'class':'a-section review aok-relative'})

# %%
reviews = []
for item in data:
  review = item.find('span',attrs={'data-hook':"review-body"}).text
  date = item.find('span',attrs={'data-hook':"review-date"}).text
  rating = item.find('i',attrs={'data-hook':"review-star-rating"}).text
  reviews.append([review,date,rating])

# %%
import pandas as pd

# %%
pd.DataFrame(reviews, columns=['Review','Date','Rating'])
# Out:
#                                               Review  ...              Rating
# 0  \n\n  I bought this product just for the Bass ...  ...  5.0 out of 5 stars
# 1  \n\n  It offers many impressive features and h...  ...  5.0 out of 5 stars
# 2  \n\n  COMFORT:I wear it during my workout I wa...  ...  5.0 out of 5 stars
# 3  \n\n  Awesome product. Bass is great. Sound qu...  ...  5.0 out of 5 stars
# 4  \n\n  This product is AMAZING!!!. you can feel...  ...  5.0 out of 5 stars
# 5  \n\n  The boAt Airdopes 441 Pro are good, stur...  ...  5.0 out of 5 stars
# 6  \n\n  The product is very goodGood rather very...  ...  5.0 out of 5 stars
# 7  \n\n  The product is great, it has all the qua...  ...  5.0 out of 5 stars
# 8  \n\n  Let's go straight to the points.Pros.1. ...  ...  5.0 out of 5 stars
# 9  \n\n  A wonderful product & worth buying it.As...  ...  5.0 out of 5 stars
#
# [10 rows x 3 columns]

# %%
item.find('span',attrs={'data-hook':"review-date"}).text
# Out:
# 'Reviewed in India on 1 October 2020'

# %%
item.find('span',attrs={'data-hook':"review-body"}).text
# Out:
# '\n\n  A wonderful product & worth buying it.As compare to other product in comparison, this product is way superiorAll parameters defined are very well covered.Main importance while buying these kund of product are :1). Durability2). Waterproof3). Comfort fitIn all parameters it fit good, I have tried it while morning jogging and also tried wearing while washing face.Also a good magnetic conteoll while charging.Shall also edit review after using it for 3 weekUPDATE AFTER 4 MONTHS OF USAGESTILL WORKING AS BEAUTIFULLY AS BEFORE, I would say in this range this product has an amazing quality build & durability along with clear sound.Value for money product with good brand support\n\n'

# %%
reviews=[]
for i in range (1,50):
  url = "https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_"+str(i)+"?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber="+str(i)+"#reviews-filter-bar"
  r = requests.get(url)
  content=r.content
  soup = BeautifulSoup(content)
  data = soup.find_all('div',attrs={'class':'a-section review aok-relative'})
  print(url)
  for item in data:
     review = item.find('span',attrs={'data-hook':"review-body"}).text
     date = item.find('span',attrs={'data-hook':"review-date"}).text
     rating = item.find('i',attrs={'data-hook':"review-star-rating"}).text
     reviews.append([review,date,rating])
# Out:
# https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_1?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar
# https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=2#reviews-filter-bar
# https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_3?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=3#reviews-filter-bar
# https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_4?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=4#reviews-filter-bar
# https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=5#reviews-filter-bar
# ...

# %%
url
# Out:
# 'https://www.amazon.in/product-reviews/B084DS51NC/ref=cm_cr_arp_d_paging_btm_next_49?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews&pageNumber=49#reviews-filter-bar'

# %%
df = pd.DataFrame(reviews, columns=['Review','Date','Rating'])

# %%
df
# Out:
#                                                 Review  ...              Rating
# 0    \n\n  Its a really good pair of Airdopes. Good...  ...  5.0 out of 5 stars
# 1    \n\n  Really impressed with the fastest delive...  ...  5.0 out of 5 stars
# 2    \n\n  I have been researching about getting a ...  ...  5.0 out of 5 stars
# 3    \n\n  * It's my first ever truly wireless buds...  ...  5.0 out of 5 stars
# 4    \n\n  If you are a fan of bass like I am, hell...  ...  5.0 out of 5 stars
# ..                                                 ...  ...                 ...
# 255  \n\n  First let's talk about package. It was r...  ...  5.0 out of 5 stars
# 256  \n\n  The product was really awsome and the so...  ...  5.0 out of 5 stars
# 257  \n\n  I Recommend you purchase the product. It...  ...  5.0 out of 5 stars
# 258  \n\n  Very attractive airdopes , sound quality...  ...  5.0 out of 5 stars
# 259  \n\n  Great product everything is super solid ...  ...  5.0 out of 5 stars
#
# ...

# %%
df.head()
# Out:
#                                               Review  ...              Rating
# 0  \n\n  Its a really good pair of Airdopes. Good...  ...  5.0 out of 5 stars
# 1  \n\n  Really impressed with the fastest delive...  ...  5.0 out of 5 stars
# 2  \n\n  I have been researching about getting a ...  ...  5.0 out of 5 stars
# 3  \n\n  * It's my first ever truly wireless buds...  ...  5.0 out of 5 stars
# 4  \n\n  If you are a fan of bass like I am, hell...  ...  5.0 out of 5 stars
#
# [5 rows x 3 columns]
