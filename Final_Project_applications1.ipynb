# %%
# Importing necessary libraries and mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scattertext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scattertext
#   Downloading scattertext-0.1.19-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 46.0 MB/s eta 0:00:00
# Collecting flashtext
#   Downloading flashtext-2.7.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy>=3.2 in /usr/local/lib/python3.9/dist-packages (from scattertext) (3.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.2.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from scattertext) (0.13.5)
# Requirement already satisfied: gensim>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=4.0.0->scattertext) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (67.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (23.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (8.1.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.4.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.10.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.27.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->scattertext) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels->scattertext) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.2->scattertext) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy>=3.2->scattertext) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy>=3.2->scattertext) (2.1.2)
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9308 sha256=093f666dc76392099132b5733564f139a68cc3a3bba16ec14a3fa95fcc11a97f
#   Stored in directory: /root/.cache/pip/wheels/65/3c/c7/44672c5062c16d05760b1eaddbf611d2f6a4b715c6d6777418
# Successfully built flashtext
# Installing collected packages: flashtext, scattertext
# Successfully installed flashtext-2.7 scattertext-0.1.19

# %%
import scattertext as st
import spacy
from pprint import pprint
import pandas as pd
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score
import pickle
import nltk

# %%
# Downloading necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv('/content/drive/MyDrive/NLP_Applications_1/Project/IMDB.csv')

# %%
# Printing the dataset
print(df)
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
# Counting the number of positive and negative labels in the dataset
positive_labels = (df['sentiment'] == "positive").sum()
negative_labels = (df['sentiment'] == "negative").sum()

# %%
# Printing the number of positive and negative labels in the dataset
print(f"Number of positive labels: {positive_labels}")
print(f"Number of negative labels: {negative_labels}")
# Out:
# Number of positive labels: 25000
# Number of negative labels: 25000

# %%
# Cleaning the review text by removing HTML tags
def clean(text):
    cleaned = re.compile(r'<.*?>')
    return re.sub(cleaned,'',text)

data = df
data.loc[:, 'review'] = data['review'].apply(clean)

# %%
# Removing non-alphanumeric characters from the review text
def is_special(text):
    rem = ''
    for i in text:
        if i.isalnum():
            rem = rem + i
        else:
            rem = rem + ' '
    return rem

data.review = data.review.apply(is_special)

# %%
# Converting review text to lowercase
def to_lower(text):
    return text.lower()

data.review = data.review.apply(to_lower)

# Removing stopwords from the review text
def rem_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    return [w for w in words if w not in stop_words]

data = data.review.apply(rem_stopwords)

# %%
# Swapping columns in the dataset
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

df = swap_columns(df, 'review', 'sentiment')

# %%
# Displaying the final dataset
display(df)
# Out:
#       sentiment                                             review
# 0      positive  one of the other reviewers has mentioned that ...
# 1      positive  a wonderful little production  the filming tec...
# 2      positive  i thought this was a wonderful way to spend ti...
# 3      negative  basically there s a family where a little boy ...
# 4      positive  petter mattei s  love in the time of money  is...
# ...         ...                                                ...
# 49995  positive  i thought this movie did a down right good job...
# 49996  negative  bad plot  bad dialogue  bad acting  idiotic di...
# 49997  negative  i am a catholic taught in parochial elementary...
# 49998  negative  i m going to have to disagree with the previou...
# 49999  negative  no one expects the star trek movies to be high...
#
# [50000 rows x 2 columns]

# %%
text = df.iloc[:2000,:]

# %%
len(text)
# Out:
# 2000

# %%
text = swap_columns(text, 'sentiment', 'review')

# %%
display(text)
# Out:
#                                                  review sentiment
# 0     one of the other reviewers has mentioned that ...  positive
# 1     a wonderful little production  the filming tec...  positive
# 2     i thought this was a wonderful way to spend ti...  positive
# 3     basically there s a family where a little boy ...  negative
# 4     petter mattei s  love in the time of money  is...  positive
# ...                                                 ...       ...
# 1995  feeling minnesota  directed by steven baigelma...  negative
# 1996  the cell  2000  rating  8 10the cell  like ant...  positive
# 1997  this movie  despite its list of b  c  and d li...  negative
# 1998  i loved this movie  it was all i could do not ...  positive
# 1999  this was the worst movie i have ever seen bill...  negative
#
# [2000 rows x 2 columns]

# %%
len(text)
# Out:
# 2000

# %%
positive_labels = (text['sentiment'] == "positive").sum()
negative_labels = (text['sentiment'] == "negative").sum()

# %%
print(f"Number of positive labels: {positive_labels}")
print(f"Number of negative labels: {negative_labels}")
# Out:
# Number of positive labels: 1005
# Number of negative labels: 995

# %%
import scattertext as st

df = text.assign(
    parse=lambda df: df.review.apply(st.whitespace_nlp_with_sentences))
corpus = st.CorpusWithoutCategoriesFromParsedDocuments(
    df, parsed_col='parse'
).build().get_unigram_corpus().remove_infrequent_words(minimum_term_count=6)

corpus.get_categories()
# Returns ['_']
# Out:
# ['_']

# %%
dispersion = st.Dispersion(corpus)

dispersion_df = dispersion.get_df()
dispersion_df.head(3)
# Out:
#      Frequency  Range         SD        VC  Juilland's D  Rosengren's S  \
# one       2041   1101   1.317604  1.291136      0.970825       0.596722
# of       11327   1891   5.236532  0.924611      0.987110       0.927564
# the      26166   1982  11.198621  0.855967      0.990988       0.966736
#
#            DP   DP norm  KL-divergence
# one  0.415829  0.415846       0.880308
# of   0.185104  0.185112       0.176035
# the  0.136101  0.136107       0.090568

# %%
dispersion_df = dispersion_df.assign(
    X=lambda df: df.Frequency,
    Xpos=lambda df: st.Scalers.log_scale(df.X),
    Y=lambda df: df["Rosengren's S"],
    Ypos=lambda df: st.Scalers.scale(df.Y),
)

# %%
html = st.dataframe_scattertext(
    corpus,
    plot_df=dispersion_df,
    metadata=corpus.get_df()['sentiment'] + ' (' + corpus.get_df()['review'].str.upper() + ')',
    ignore_categories=True,
    x_label='Log Frequency',
    y_label="Rosengren's S",
    y_axis_labels=['Less Dispersion', 'Medium', 'More Dispersion'],
)
# Out:
# /usr/local/lib/python3.9/dist-packages/scattertext/Scalers.py:247: RuntimeWarning: invalid value encountered in true_divide
#   vec_ss = (vec_ss - vec_ss.min()) * 1. / (vec_ss.max() - vec_ss.min())

# %%
nlp = spacy.load("en_core_web_sm")
corpus = st.CorpusFromPandas(text, 
                            category_col='sentiment', 
                             text_col='review',
                             nlp=nlp).build()

# %%
print(list(corpus.get_scaled_f_scores_vs_background().index[:10]))
# Out:
# ['fulci', 'cinematography', 'slasher', 'believable', 'likable', 'laughable', 'hadn', 'filmed', 'cheesy', 'watchable']

# %%
term_freq_df = corpus.get_term_freq_df()
term_freq_df['positive_Score'] = corpus.get_scaled_f_scores('positive')
pprint(list(term_freq_df.sort_values(by='positive_Score', ascending=False).index[:10]))
# Out:
# ['excellent',
#  'wonderful',
#  'loved',
#  'perfect',
#  'war',
#  'the best',
#  'performances',
#  'a great',
#  'great',
#  'beautiful']

# %%
term_freq_df['negative_Score'] = corpus.get_scaled_f_scores('negative')
pprint(list(term_freq_df.sort_values(by='negative_Score', ascending=False).index[:10]))
# Out:
# ['the worst',
#  'waste',
#  'awful',
#  'worst',
#  'boring',
#  'stupid',
#  'terrible',
#  'bad',
#  't even',
#  'worse']

# %% [markdown]
# #Visualizing term associations

# %%
html = st.produce_scattertext_explorer(corpus,
         category ='negative',
         category_name ='Negative',
          not_category_name ='Positive',
         width_in_pixels = 1000,
         metadata = text['review'])
open("sentiment-Visualization.html", 'wb').write(html.encode('utf-8'))
# Out:
# 6954594

# %% [markdown]
# #Scattertext 0.1.19

# %%
import scattertext as st

corpus = st.CorpusFromPandas(
    text, category_col='sentiment', text_col='review',
    nlp=st.whitespace_nlp_with_sentences
).build().get_unigram_corpus().compact(st.AssociationCompactor(2000))

html = st.produce_scattertext_explorer(
    corpus,
    category='positive', category_name='Positive', not_category_name='Negative',
    minimum_term_frequency=0, pmi_threshold_coefficient=0,
    width_in_pixels=1000, metadata=corpus.get_df()['sentiment'],
    transform=st.Scalers.dense_rank
)
open('./demo_compact.html', 'w').write(html)
# Out:
# 3528206

# %%
# !pip install --pre html5lib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.9/dist-packages (1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib) (1.16.0)

# %% [markdown]
# #Ordering Terms by Corpus Characteristicness

# %%
import scattertext as st

corpus = (st.CorpusFromPandas(text,
                              category_col='sentiment',
                              text_col='review',
                              nlp=st.whitespace_nlp_with_sentences)
          .build()
          .get_unigram_corpus()
          .compact(st.ClassPercentageCompactor(term_count=2,
                                               term_ranker=st.OncePerDocFrequencyRanker)))
html = st.produce_characteristic_explorer(
	corpus,
	category='negative',
	category_name='negative',
	not_category_name='positive',
	metadata=corpus.get_df()['review']
)
open('demo_characteristic_chart.html', 'wb').write(html.encode('utf-8'))
# Out:
# 7704144

# %% [markdown]
# #Visualizing Empath topics and categories

# %%
# !pip install scattertext empath
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scattertext in /usr/local/lib/python3.9/dist-packages (0.1.19)
# Collecting empath
#   Downloading empath-0.89.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from scattertext) (0.13.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.22.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.65.0)
# Requirement already satisfied: flashtext in /usr/local/lib/python3.9/dist-packages (from scattertext) (2.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.2.2)
# Requirement already satisfied: gensim>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.3.1)
# Requirement already satisfied: spacy>=3.2 in /usr/local/lib/python3.9/dist-packages (from scattertext) (3.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from empath) (2.27.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=4.0.0->scattertext) (6.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (23.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.10.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (67.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.4.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (8.1.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->empath) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->empath) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->empath) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->empath) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->scattertext) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels->scattertext) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.2->scattertext) (4.5.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy>=3.2->scattertext) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy>=3.2->scattertext) (2.1.2)
# Building wheels for collected packages: empath
#   Building wheel for empath (setup.py) ... done
#   Created wheel for empath: filename=empath-0.89-py3-none-any.whl size=57823 sha256=62bb9d561a47a34dd6589f86adeff0a291a876a43742d925a76487b35d7bf500
#   Stored in directory: /root/.cache/pip/wheels/5b/58/77/7eed8eef4c6be0cca8920ac319d916811537a37407da220bf1
# Successfully built empath
# Installing collected packages: empath
# Successfully installed empath-0.89

# %%
feat_builder = st.FeatsFromOnlyEmpath()

# %%
corpus = st.CorpusFromParsedDocuments(text,
                                            category_col='sentiment',
                                             feats_from_spacy_doc=feat_builder,
                                             parsed_col='review').build()

# %%
html = st.produce_scattertext_explorer(corpus,
                                        category='negative',
                                        category_name='negative',
                                       not_category_name='positive',
                                       width_in_pixels=1000,
                                        metadata=text['review'],
                                       use_non_text_features=True,
                                       use_full_doc=True,
                                       topic_model_term_lists=feat_builder.get_top_model_term_lists())
open("Convention-Visualization-Empath.html", 'wb').write(html.encode('utf-8'))
# Out:
# 7232582

# %% [markdown]
# #Developing and using bespoke word representations

# %%
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.22.4)

# %%
import spacy
from gensim.models import word2vec
from scattertext import SampleCorpora, word_similarity_explorer_gensim, Word2VecFromParsedCorpus
from scattertext.CorpusFromParsedDocuments import CorpusFromParsedDocuments

nlp = spacy.load("en_core_web_sm")
convention_df_1 = text
convention_df_1['parsed'] = convention_df_1.review.apply(nlp)
corpus = CorpusFromParsedDocuments(convention_df_1, category_col='sentiment', parsed_col='parsed').build()

model = word2vec.Word2Vec(vector_size=300,
                          alpha=0.025,
                          window=5,
                          min_count=5,
                          max_vocab_size=None,
                          sample=0,
                          seed=1,
                          workers=1,
                          min_alpha=0.0001,
                          sg=1,
                          hs=1,
                          negative=0,
                          cbow_mean=0,
                          epochs=1,
                          null_word=0,
                          trim_rule=None,
                          sorted_vocab=1)

# %%
html = word_similarity_explorer_gensim(corpus,
                                       category='negative',
                                       category_name='negative',
                                       not_category_name='positive',
                                       target_term='bad',
                                       minimum_term_frequency=5,
                                       pmi_threshold_coefficient=4,
                                       width_in_pixels=1000,
                                       metadata=text['review'],
                                       word2vec=Word2VecFromParsedCorpus(corpus, model).train(),
                                       max_p_val=0.05,
                                       save_svg_button=True)
open('./demo_gensim_similarity.html', 'wb').write(html.encode('utf-8'))
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING:gensim.models.word2vec:EPOCH 325: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 326: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 327: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 328: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 329: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 330: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 331: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 332: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 333: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 334: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 335: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 336: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 337: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 338: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 339: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 340: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 341: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 342: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 343: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 344: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 345: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 346: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 347: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 348: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 349: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 350: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 351: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 352: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 353: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 354: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 355: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 356: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 357: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 358: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 359: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 360: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 361: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 362: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 363: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 364: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 365: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 366: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 367: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 368: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 369: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 370: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 371: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 372: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 373: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 374: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 375: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 376: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 377: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 378: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 379: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 380: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 381: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 382: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 383: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 384: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 385: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 386: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 387: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 388: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 389: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 390: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 391: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 392: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 393: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 394: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 395: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 396: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 397: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 398: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 399: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 400: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 401: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 402: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 403: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 404: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 405: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 406: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 407: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 408: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 409: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 410: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 411: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 412: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 413: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 414: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 415: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 416: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 417: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 418: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 419: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 420: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 421: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 422: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 423: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 424: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 425: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 426: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 427: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 428: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 429: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 430: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 431: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 432: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 433: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 434: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 435: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 436: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 437: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 438: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 439: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 440: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 441: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 442: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 443: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 444: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 445: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 446: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 447: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 448: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 449: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 450: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 451: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 452: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 453: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 454: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 455: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 456: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 457: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 458: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 459: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 460: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 461: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 462: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 463: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 464: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 465: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 466: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 467: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 468: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 469: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 470: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 471: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 472: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 473: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 474: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 475: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 476: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 477: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 478: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 479: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 480: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 481: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 482: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 483: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 484: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 485: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 486: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 487: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 488: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 489: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 490: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 491: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 492: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 493: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 494: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 495: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 496: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 497: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 498: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 499: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 500: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 501: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 502: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 503: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 504: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 505: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 506: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 507: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 508: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 509: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 510: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 511: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 512: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 513: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 514: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 515: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 516: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 517: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 518: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 519: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 520: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 521: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 522: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 523: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 524: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 525: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 526: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 527: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 528: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 529: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 530: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 531: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 532: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 533: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 534: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 535: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 536: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 537: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 538: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 539: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 540: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 541: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 542: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 543: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 544: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 545: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 546: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 547: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 548: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 549: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 550: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 551: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 552: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 553: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 554: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 555: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 556: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 557: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 558: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 559: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 560: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 561: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 562: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 563: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 564: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 565: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 566: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 567: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 568: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 569: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 570: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 571: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 572: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 573: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 574: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 575: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 576: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 577: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 578: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 579: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 580: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 581: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 582: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 583: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 584: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 585: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 586: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 587: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 588: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 589: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 590: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 591: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 592: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 593: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 594: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 595: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 596: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 597: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 598: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 599: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 600: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 601: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 602: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 603: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 604: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 605: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 606: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 607: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 608: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 609: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 610: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 611: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 612: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 613: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 614: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 615: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 616: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 617: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 618: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 619: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 620: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 621: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 622: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 623: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 624: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 625: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 626: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 627: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 628: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 629: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 630: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 631: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 632: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 633: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 634: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 635: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 636: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 637: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 638: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 639: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 640: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 641: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 642: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 643: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 644: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 645: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 646: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 647: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 648: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 649: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 650: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 651: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 652: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 653: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 654: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 655: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 656: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 657: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 658: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 659: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 660: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 661: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 662: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 663: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 664: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 665: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 666: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 667: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 668: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 669: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 670: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 671: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 672: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 673: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 674: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 675: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 676: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 677: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 678: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 679: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 680: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 681: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 682: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 683: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 684: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 685: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 686: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 687: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 688: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 689: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 690: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 691: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 692: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 693: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 694: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 695: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 696: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 697: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 698: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 699: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 700: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 701: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 702: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 703: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 704: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 705: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 706: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 707: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 708: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 709: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 710: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 711: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 712: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 713: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 714: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 715: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 716: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 717: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 718: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 719: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 720: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 721: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 722: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 723: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 724: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 725: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 726: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 727: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 728: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 729: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 730: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 731: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 732: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 733: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 734: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 735: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 736: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 737: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 738: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 739: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 740: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 741: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 742: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 743: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 744: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 745: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 746: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 747: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 748: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 749: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 750: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 751: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 752: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 753: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 754: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 755: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 756: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 757: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 758: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 759: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 760: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 761: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 762: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 763: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 764: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 765: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 766: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 767: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 768: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 769: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 770: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 771: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 772: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 773: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 774: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 775: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 776: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 777: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 778: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 779: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 780: supplied example count (0) did not equal expected count (4666)
# ...
# WARNING:gensim.models.word2vec:EPOCH 1684: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1685: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1686: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1687: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1688: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1689: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1690: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1691: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1692: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1693: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1694: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1695: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1696: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1697: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1698: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1699: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1700: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1701: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1702: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1703: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1704: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1705: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1706: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1707: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1708: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1709: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1710: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1711: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1712: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1713: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1714: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1715: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1716: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1717: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1718: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1719: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1720: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1721: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1722: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1723: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1724: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1725: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1726: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1727: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1728: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1729: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1730: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1731: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1732: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1733: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1734: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1735: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1736: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1737: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1738: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1739: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1740: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1741: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1742: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1743: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1744: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1745: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1746: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1747: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1748: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1749: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1750: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1751: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1752: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1753: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1754: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1755: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1756: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1757: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1758: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1759: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1760: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1761: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1762: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1763: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1764: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1765: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1766: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1767: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1768: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1769: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1770: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1771: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1772: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1773: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1774: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1775: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1776: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1777: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1778: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1779: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1780: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1781: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1782: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1783: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1784: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1785: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1786: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1787: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1788: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1789: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1790: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1791: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1792: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1793: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1794: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1795: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1796: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1797: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1798: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1799: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1800: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1801: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1802: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1803: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1804: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1805: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1806: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1807: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1808: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1809: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1810: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1811: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1812: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1813: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1814: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1815: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1816: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1817: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1818: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1819: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1820: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1821: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1822: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1823: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1824: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1825: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1826: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1827: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1828: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1829: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1830: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1831: supplied example count (0) did not equal expected count (4666)
# WARNING:gensim.models.word2vec:EPOCH 1832: supplied example count (0) did not equal expected count (4666)
# /usr/local/lib/python3.9/dist-packages/scattertext/Scalers.py:247: RuntimeWarning: invalid value encountered in true_divide
#   vec_ss = (vec_ss - vec_ss.min()) * 1. / (vec_ss.max() - vec_ss.min())
# 7306368

# %% [markdown]
# #Visualizing any kind of term score

# %%
from sklearn.linear_model import Lasso
from scattertext import sparse_explorer
html = sparse_explorer(corpus,
                        category='negative',
                        category_name='negative',
                        not_category_name='positive',
                        scores = corpus.get_regression_coefs('negative', Lasso(max_iter=10000)),
                        minimum_term_frequency=5,
                       pmi_threshold_coefficient=4,
                       width_in_pixels=1000,
                       metadata=text['review'])
open('./Convention-Visualization-Sparse.html', 'wb').write(html.encode('utf-8'))
# Out:
# /usr/local/lib/python3.9/dist-packages/scattertext/TermDocMatrixFilter.py:42: RuntimeWarning: invalid value encountered in log
#   return np.log(
# 7339843

# %% [markdown]
# #Custom term positions

# %%
def scale(ar):
  return (ar - ar.min()) / (ar.max() - ar.min())

# %%
def zero_centered_scale(ar):
      ar[ar > 0] = scale(ar[ar > 0])
      ar[ar < 0] = -scale(-ar[ar < 0])
      return (ar + 1) / 2.

# %%
from sklearn.linear_model import LogisticRegression

# %%
import numpy as np

# %%
frequencies_scaled = scale(np.log(term_freq_df.sum(axis=1).values))

# %%
scores = corpus.get_logreg_coefs('negative',
                                 LogisticRegression(penalty='l2', C=10, max_iter=10000, n_jobs=-1))

# %%
scores_scaled = zero_centered_scale(scores)

# %%
# !pip install scattertext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scattertext in /usr/local/lib/python3.9/dist-packages (0.1.19)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.65.0)
# Requirement already satisfied: flashtext in /usr/local/lib/python3.9/dist-packages (from scattertext) (2.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.5.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from scattertext) (0.13.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.22.4)
# Requirement already satisfied: gensim>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from scattertext) (4.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.10.1)
# Requirement already satisfied: spacy>=3.2 in /usr/local/lib/python3.9/dist-packages (from scattertext) (3.5.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from scattertext) (1.2.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=4.0.0->scattertext) (6.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.10.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.4.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (23.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (8.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (67.6.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy>=3.2->scattertext) (1.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->scattertext) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->scattertext) (1.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->scattertext) (0.5.3)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels->scattertext) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.2->scattertext) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.2->scattertext) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.2->scattertext) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy>=3.2->scattertext) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy>=3.2->scattertext) (2.1.2)

# %%
from scattertext import produce_scattertext_explorer

# %%
html = produce_scattertext_explorer(corpus,
                                   category='negative',
                                     category_name='negative',
                                     not_category_name='positive',
                                     minimum_term_frequency=5,
                                     pmi_threshold_coefficient=4,
                                     width_in_pixels=1000,
                                     x_coords=frequencies_scaled,
                                     y_coords=scores_scaled,
                                     scores=scores,
                                     sort_by_dist=False,
                                     metadata=text['review'],
                                     x_label='Log frequency',
                                     y_label='L2-penalized logistic regression coef')
open('demo_custom_coordinates.html', 'wb').write(html.encode('utf-8'))
# Out:
# 7363341
